# %%
# derste aldığım notlar 19

import numpy as np
import matplotlib.pyplot as matplot

# %%
maasListesi = np.random.normal(4000,500,1000) #4000 tl civarında 500 tl standart sapmalı 1000 tane veri oluşturur.
np.mean(maasListesi)
# Out:
# 4002.827647697362

# %%
matplot.hist(maasListesi,50)
matplot.show()
